# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# # **Text to video generation using Large Language Models (LLMs)**

# %% [markdown]
# # Setting up the environment

# %%
# Cloning the repository 
# !git clone https://github.com/Picsart-AI-Research/Text2Video-Zero.git
# !git clone https://github.com/nimamasoumi/LLM-Video-Gen

# Installing Python 3.9 and relevent packages
# !apt install python3.9
# !apt install python3.9-distutils
# !pip3 install virtualenv
# !pip3 install argparse

# %%
# Setting up the Python virtual environment
# %cd /content/Text2Video-Zero/
# !virtualenv --system-site-packages -p python3.9 venv
# !source /content/Text2Video-Zero/venv/bin/activate; pip3 install -r requirements.txt

# %%
# Preparing the files for inference
# %cd /content/Text2Video-Zero/
# !source /content/Text2Video-Zero/venv/bin/activate; cp /content/LLM-Video-Gen/inference-text2video.py .
# !source /content/Text2Video-Zero/venv/bin/activate; cp /content/LLM-Video-Gen/inference-edgeControl.py .
# !source /content/Text2Video-Zero/venv/bin/activate; cp /content/LLM-Video-Gen/inference-poseControl.py .
# !source /content/Text2Video-Zero/venv/bin/activate; cp /content/LLM-Video-Gen/inference-depthControl.py .

# %% [markdown]
# # Performing inference

# %%
# Generate Text-to-Video results using the inference Python file
# !source /content/Text2Video-Zero/venv/bin/activate; python3 inference-text2video.py --prompt "a gray fox roaring"

# %%
# Generate Video-to-Video edge control results using the inference Python file
# !source /content/Text2Video-Zero/venv/bin/activate; python3 inference-edgeControl.py --prompt "oil painting of a fox, a high-quality, detailed, and professional photo"

# %%
# Generate the Video-to-Video pose control results using the inference Python file
# !source /content/Text2Video-Zero/venv/bin/activate; python3 inference-poseControl.py --prompt "a fox walking"

# %%
# Generate the Video-to-Video depth control results using the inference Python file
# !source /content/Text2Video-Zero/venv/bin/activate; python3 inference-depthControl.py --prompt "oil painting of a fox, a high-quality, detailed, and professional photo"
